# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset 1

# %%
data1 = pd.read_csv(r'C:\Users\hephz\OneDrive\Documents\GitHub\div_lessons\Hackathon_Team6\covid19vacbydemographics.csv')
data1 
data1.head()
# Out:
#   demographic_category demographic_value administered_date  total_doses  \
# 0            Age Group             18-49        08/03/2022         8219
# 1            Age Group             50-64        08/03/2022         2937
# 2            Age Group               65+        08/03/2022         1951
# 3            Age Group            Dec-17        08/03/2022         1919
# 4            Age Group            05-Nov        08/03/2022         3298
#
#    cumulative_total_doses  pfizer_doses  cumulative_pfizer_doses  \
# 0                33212597          5311                 19574942
# 1                16332473          1651                  8659419
# 2                14770183           973                  6934877
# 3                 5213509          1905                  5192333
# 4                 2484587            67                    38657
#
#    moderna_doses  cumulative_moderna_doses  jj_doses  cumulative_jj_doses  \
# ...

# %%
#data1.head()
data1.info()
data1.demographic_category.value_counts()
data1.demographic_category.unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9617 entries, 0 to 9616
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   demographic_category            9617 non-null   object
#  1   demographic_value               9617 non-null   object
#  2   administered_date               9617 non-null   object
#  3   total_doses                     9617 non-null   int64
#  4   cumulative_total_doses          9617 non-null   int64
#  5   pfizer_doses                    9617 non-null   int64
#  6   cumulative_pfizer_doses         9617 non-null   int64
#  7   moderna_doses                   9617 non-null   int64
#  8   cumulative_moderna_doses        9617 non-null   int64
#  9   jj_doses                        9617 non-null   int64
#  10  cumulative_jj_doses             9617 non-null   int64
#  11  partially_vaccinated            9617 non-null   int64
# ...

# %%
data1.head()
data1.tail()
data1.columns
## there is no numm value in the data set
data1.isnull().sum()
data1.groupby('pfizer_doses').count()
## data1 = travel_data[travel_data['TravelInsurance'] == 1]
data1.head()
# Out:
#   demographic_category demographic_value administered_date  total_doses  \
# 0            Age Group             18-49        08/03/2022         8219
# 1            Age Group             50-64        08/03/2022         2937
# 2            Age Group               65+        08/03/2022         1951
# 3            Age Group            Dec-17        08/03/2022         1919
# 4            Age Group            05-Nov        08/03/2022         3298
#
#    cumulative_total_doses  pfizer_doses  cumulative_pfizer_doses  \
# 0                33212597          5311                 19574942
# 1                16332473          1651                  8659419
# 2                14770183           973                  6934877
# 3                 5213509          1905                  5192333
# 4                 2484587            67                    38657
#
#    moderna_doses  cumulative_moderna_doses  jj_doses  cumulative_jj_doses  \
# ...

# %%
data1.info()
data1.isnull().sum()
##descriptiive statistics
data1.describe() 
## it gives mean, mode e.t.c
## data1.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9617 entries, 0 to 9616
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   demographic_category            9617 non-null   object
#  1   demographic_value               9617 non-null   object
#  2   administered_date               9617 non-null   object
#  3   total_doses                     9617 non-null   int64
#  4   cumulative_total_doses          9617 non-null   int64
#  5   pfizer_doses                    9617 non-null   int64
#  6   cumulative_pfizer_doses         9617 non-null   int64
#  7   moderna_doses                   9617 non-null   int64
#  8   cumulative_moderna_doses        9617 non-null   int64
#  9   jj_doses                        9617 non-null   int64
#  10  cumulative_jj_doses             9617 non-null   int64
#  11  partially_vaccinated            9617 non-null   int64
# ...

# %%
area_array = np.array(data1['total_doses'])
plt.hist(area_array, bins =18)
plt.show()

# %%
#data1['demographic_category']
data1.columns
data1[['demographic_category', 'demographic_value', 'administered_date',
       'total_doses',  'pfizer_doses',
         'moderna_doses', 'jj_doses', 'partially_vaccinated',
       'fully_vaccinated', 'at_least_one_dose', 'booster_recip_count',
       ]]
data1.demographic_value.unique()   
#df.Profession = df.Profession.replace({'89': 'Data engineer'})

##replacements
data1.demographic_value = data1.demographic_value.replace({'Unknown Agegroup': 'Infant'})
data1.demographic_value = data1.demographic_value.replace({'Unknown/undifferentiated': 'Male'})
data1.demographic_value = data1.demographic_value.replace({'Unknown': 'Alien'})

data1.demographic_value.unique()
# Out:
# array(['18-49', '50-64', '65+', 'Dec-17', '05-Nov', 'Infant', 'Female',
#        'Male', 'White', 'Latino', 'Asian', 'Other Race',
#        'Black or African American', 'Alien', 'Multiracial',
#        'Native Hawaiian or Other Pacific Islander',
#        'American Indian or Alaska Native'], dtype=object)

# %%
## value count for the category in the demographic column
##we can do for all rows
data1.demographic_category.value_counts()
#data1.demographic_category.unique()
# Out:
# Race/Ethnicity    4834
# Age Group         3147
# Gender            1636
# Name: demographic_category, dtype: int64

# %% [markdown]
# # Dataset 2

# %%
data2 = pd.read_csv(r'C:\Users\hephz\OneDrive\Documents\GitHub\div_lessons\Hackathon_Team6\covid19vaccinesbycounty.csv')
data2
data2.head()
data2.describe()

## data2.isnull().sum()
# Out:
#          total_doses  cumulative_total_doses   pfizer_doses  \
# count   36704.000000            3.670400e+04   36704.000000
# mean     5856.158321            1.476064e+06    3286.892873
# std     31159.634085            7.181821e+06   16977.993693
# min         0.000000            0.000000e+00       0.000000
# 25%         2.000000            4.927500e+02       1.000000
# 50%       170.000000            4.250650e+04      72.000000
# 75%      1473.250000            4.035208e+05     835.000000
# max    522665.000000            7.201982e+07  297842.000000
#
#        cumulative_pfizer_doses  moderna_doses  cumulative_moderna_doses  \
# count             3.670400e+04   36704.000000              3.670400e+04
# mean              8.294031e+05    2180.240955              5.798184e+05
# std               4.058668e+06   12700.712799              2.777301e+06
# min               0.000000e+00       0.000000              0.000000e+00
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36704 entries, 0 to 36703
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   county                          36704 non-null  object
#  1   administered_date               36704 non-null  object
#  2   total_doses                     36704 non-null  int64
#  3   cumulative_total_doses          36704 non-null  int64
#  4   pfizer_doses                    36704 non-null  int64
#  5   cumulative_pfizer_doses         36704 non-null  int64
#  6   moderna_doses                   36704 non-null  int64
#  7   cumulative_moderna_doses        36704 non-null  int64
#  8   jj_doses                        36704 non-null  int64
#  9   cumulative_jj_doses             36704 non-null  int64
#  10  partially_vaccinated            36704 non-null  int64
#  11  total_partially_vaccinated      36704 non-null  int64
# ...

# %%
data2['california_flag'] = data2['california_flag'].fillna(0) 

data2.california_flag.unique()

type(data2)

##fill all NA in cflag with 0
##data2.california_flag.unique()
##data2.california_flag.value_counts()

##pro_est_df['PRODUCTION (MT)'] = pro_est_df['PRODUCTION (MT)'].replace({'-': 0})
# Out:
# pandas.core.frame.DataFrame

# %%
data2['california_flag'].mode()
# Out:
# 0    California
# dtype: object

# %%
area_array = np.array(data2['total_doses'])
plt.hist(area_array, bins =18)
plt.show()

# %%
data2['total_doses'].mean()
data2['total_doses'].median()
data2['total_doses'].value_counts()
# Out:
# 0         7684
# 1         1126
# 2          461
# 3          345
# 4          264
#           ...
# 139574       1
# 126863       1
# 113732       1
# 87150        1
# 1756         1
# Name: total_doses, Length: 7845, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.hist(area_array, bins =22)
plt.show()

# %%
##data2.groupby(data2['pfizer_doses'])['moderna_doses'].sum().plot(kind='pie', figsize = (20,20), autopct='%1.1f%%')
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36704 entries, 0 to 36703
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   county                          36704 non-null  object
#  1   administered_date               36704 non-null  object
#  2   total_doses                     36704 non-null  int64
#  3   cumulative_total_doses          36704 non-null  int64
#  4   pfizer_doses                    36704 non-null  int64
#  5   cumulative_pfizer_doses         36704 non-null  int64
#  6   moderna_doses                   36704 non-null  int64
#  7   cumulative_moderna_doses        36704 non-null  int64
#  8   jj_doses                        36704 non-null  int64
#  9   cumulative_jj_doses             36704 non-null  int64
#  10  partially_vaccinated            36704 non-null  int64
#  11  total_partially_vaccinated      36704 non-null  int64
# ...

# %%
plt.figure(figsize=(5,7)
plt.boxplot(area_array)
plt.show()
# Out:
#   File "C:\Users\hephz\AppData\Local\Temp/ipykernel_18220/3013728828.py", line 2
#     plt.boxplot(area_array)
#     ^
# SyntaxError: invalid syntax
